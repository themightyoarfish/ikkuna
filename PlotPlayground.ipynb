# %%
# this helps in principle, but when this line is executed again, it seems that autoreload gets disabled #wtf
# %load_ext autoreload

# %%
# %matplotlib notebook
# %autoreload 2

import sys; sys.path.insert(0, '.') # gotta add path to project root
from experiments.learning_rate.alexnetmini.playground import main

# %%
main()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of classes: 10
# Data shape: (50000, 32, 32, 3)
# Adding  /features/conv2d0
# Adding  /features/relu0
# Adding  /features/conv2d1
# Adding  /features/relu1
# Adding  /features/maxpool2d0
# Adding  /classifier/dropout0
# Adding  /classifier/linear0
# Adding  /classifier/relu0
# Adding  /classifier/dropout1
# Adding  /classifier/linear1
# Adding  /classifier/softmax0
# Using SGD optimizer
# Registering topic train_accuracy
# Registering topic test_accuracy
# Registering topic weights_spectral_norm
# Registering topic weight_updates_weights_ratio
# Registering topic activations_variance
# Registering topic weights_norm2
# Registering topic activations_norm2
# Registering topic layer_gradients_norm2
# Starting epoch 0
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/container.py:91: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
