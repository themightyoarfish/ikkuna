# %%
# this helps in principle, but when this line is executed again, it seems that autoreload gets disabled #wtf
# %load_ext autoreload

# %%
# %matplotlib notebook
# %autoreload 2

import sys; sys.path.insert(0, '.') # gotta add path to project root
from experiments.ratio_loss_correlation.experiment_plotter import scatter_ratio_v_loss_decrease
scatter_ratio_v_loss_decrease(['AlexNetMini'], ['Adam'], [0.001, 0.01, 0.05, 0.1], n_epochs=75, filter=True, filter_size=50, unify_limits=True)
# Out:
# /home/share/miniconda3/envs/torch/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/share/miniconda3/envs/torch/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# <img src="data:image/png;base64,..." width="1024">
# <img src="data:image/png;base64,..." width="1024">
# <img src="data:image/png;base64,..." width="1024">
