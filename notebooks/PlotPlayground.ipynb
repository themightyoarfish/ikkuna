# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'AlexNetMini', 256, 5, 'Adam', average=10, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 195
# Number of classes: 10
# Data shape: (32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# epoch     0/4     | batch   194/194   | 15.6 b/s
# Test accuracy: 0.4892
# epoch     1/4     | batch   194/194   | 16.1 b/s
# Test accuracy: 0.5255
# epoch     2/4     | batch   194/194   | 16.2 b/s
# Test accuracy: 0.6030
# epoch     3/4     | batch   194/194   | 16.4 b/s
# Test accuracy: 0.6781
# epoch     4/4     | batch    14/194   | 16.4 b/s
