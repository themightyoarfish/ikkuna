# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'AlexNetMini', 128, 1, 'Adam')
# Out:
# ['..', '', '/home/share/miniconda3/envs/torch/lib/python36.zip', '/home/share/miniconda3/envs/torch/lib/python3.6', '/home/share/miniconda3/envs/torch/lib/python3.6/lib-dynload', '/home/share/miniconda3/envs/torch/lib/python3.6/site-packages', '/home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg', '/home/justinshenk/inception/deepreplay', '/home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torchvision-0.2.0-py3.6.egg', '/home/share/miniconda3/envs/torch/lib/python3.6/site-packages/IPython/extensions', '/home/rasmus/.ipython']
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 391
# Number of classes: 10
# Data shape: (32, 32, 3)
# Using Adam optimizer
# epoch     1/1     | batch     1/391   | 1.5 b/s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
