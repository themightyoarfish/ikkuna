# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR100', 'AlexNetMini', 128, 50, 'Adam', average=32, ylims=(-0.1, 0.1))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 391
# Number of classes: 100
# Data shape: (32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# epoch     0/49    | batch   390/390   | 17.8 b/s
# Test accuracy: 0.0923
# epoch     1/49    | batch   390/390   | 18.2 b/s
# Test accuracy: 0.1786
# epoch     2/49    | batch   390/390   | 18.3 b/s
# Test accuracy: 0.2393
# epoch     3/49    | batch   390/390   | 18.3 b/s
# Test accuracy: 0.2744
# epoch     4/49    | batch   390/390   | 18.3 b/s
# Test accuracy: 0.2958
# epoch     5/49    | batch   390/390   | 18.4 b/s
# Test accuracy: 0.3198
# epoch     6/49    | batch   390/390   | 18.4 b/s
# Test accuracy: 0.3418
# epoch     7/49    | batch   390/390   | 18.4 b/s
# Test accuracy: 0.3379
# epoch     8/49    | batch   390/390   | 18.8 b/s
# Test accuracy: 0.3603
# epoch     9/49    | batch   390/390   | 19.3 b/s
# Test accuracy: 0.3629
# ...
