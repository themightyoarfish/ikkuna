# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR100', 'AlexNetMini', 128, 50, 'Adam', average=50, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 391
# Number of classes: 100
# Data shape: (32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# epoch     0/49    | batch   390/390   | 24.8 b/s
# Test accuracy: 0.1025
# epoch     1/49    | batch   390/390   | 25.4 b/s
# Test accuracy: 0.1756
# epoch     2/49    | batch   390/390   | 25.5 b/s
# Test accuracy: 0.2350
# epoch     3/49    | batch   390/390   | 25.6 b/s
# Test accuracy: 0.2778
# epoch     4/49    | batch   390/390   | 25.6 b/s
# Test accuracy: 0.3009
# epoch     5/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3118
# epoch     6/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3302
# epoch     7/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3478
# epoch     8/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3640
# epoch     9/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3622
# epoch    10/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3820
# epoch    11/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3822
# epoch    12/49    | batch   390/390   | 25.7 b/s
# Test accuracy: 0.3881
# epoch    13/49    | batch   390/390   | 25.7 b/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-cab61d3a5858> in <module>()
#       2 import sys; sys.path.insert(0, '..') # gotta add path to project root
#       3 from main import _main
# ----> 4 _main('CIFAR100', 'AlexNetMini', 128, 50, 'Adam', average=32, ylims=(-0.1, 0.1))
#
# /home/share/software/ai_ikkuna/main.py in _main(dataset_str, model_str, batch_size, epochs, optimizer, **kwargs)
#     154                   f'| {1. / (cum_time / n_batches):<3.1f} b/s', end='')
#     155
# --> 156         accuracy = trainer.test(dataset_test)
#     157         print('')
#     158         print(f'Test accuracy: {accuracy:3.4f}')
#
# /home/share/software/ai_ikkuna/train/train.py in test(self, dataset)
#     142         num_correct = 0
#     143         n = 0
# --> 144         for X, _labels in test_loader:
#     145             n           += X.shape[0]
#     146             predictions  = self._model(X.cuda()).argmax(1)
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     312         if self.num_workers == 0:  # same-process loading
#     313             indices = next(self.sample_iter)  # may raise StopIteration
# --> 314             batch = self.collate_fn([self.dataset[i] for i in indices])
#     315             if self.pin_memory:
#     316                 batch = pin_memory_batch(batch)
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/datasets/cifar.py in __getitem__(self, index)
#     116         # doing this so that it is consistent with all other datasets
#     117         # to return a PIL Image
# --> 118         img = Image.fromarray(img)
#     119
#     120         if self.transform is not None:
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2448             obj = obj.tostring()
#    2449
# -> 2450     return frombuffer(mode, size, obj, "raw", rawmode, 0, 1)
#    2451
#    2452
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2401             return im
#    2402
# -> 2403     return frombytes(mode, size, data, decoder_name, args)
#    2404
#    2405
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2333         args = mode
#    2334
# -> 2335     im = new(mode, size)
#    2336     im.frombytes(data, decoder_name, args)
#    2337     return im
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/PIL/Image.py in new(mode, size, color)
#    2297         color = ImageColor.getcolor(color, mode)
#    2298
# -> 2299     return Image()._new(core.fill(mode, size, color))
#    2300
#    2301
#
# KeyboardInterrupt:
