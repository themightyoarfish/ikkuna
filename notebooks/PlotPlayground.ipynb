# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR100', 'AlexNetMini', 128, 50, 'Adam', average=50, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 391
# Number of classes: 100
# Data shape: (32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# epoch     0/49    | batch   390/390   | 24.5 b/s
# Test accuracy: 0.1026
# epoch     1/49    | batch   390/390   | 24.9 b/s
# Test accuracy: 0.1719
# epoch     2/49    | batch   390/390   | 25.0 b/s
# Test accuracy: 0.2444
# epoch     3/49    | batch   390/390   | 25.2 b/s
# Test accuracy: 0.2704
# epoch     4/49    | batch   390/390   | 25.3 b/s
# Test accuracy: 0.2997
# epoch     5/49    | batch   390/390   | 25.3 b/s
# Test accuracy: 0.3320
# epoch     6/49    | batch   390/390   | 25.3 b/s
# Test accuracy: 0.3506
# epoch     7/49    | batch   390/390   | 25.3 b/s
# Test accuracy: 0.3564
# epoch     8/49    | batch   390/390   | 25.4 b/s
# Test accuracy: 0.3689
# epoch     9/49    | batch   390/390   | 25.4 b/s
# Test accuracy: 0.3769
# ...
