# %%
# this helps in principle, but when this line is executed again, it seems that autoreload gets disabled #wtf
# %load_ext autoreload

# %%
# %matplotlib notebook
# %autoreload 2

import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'DenseNet', 128, 4, 'Adam', average=8, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of classes: 10
# Data shape: (50000, 32, 32, 3)
# Using Adam optimizer
# ../ikkuna/utils/utils.py:78: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# <img src="data:image/png;base64,..." width="640">
# Batches per epoch: 391
# epoch     0/3     | batch   390/390   | 1.3 b/s
# Test accuracy: 0.6116
# epoch     1/3     | batch   205/390   | 1.3 b/s
