# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('MNIST', 'AlexNetMini', 1024, 10, 'Adam')
# Out:
# Data size: 60000
# Batches per epoch: 59
# Number of classes: 10
# Data shape: (28, 28, 1)
# <img src="data:image/png;base64,..." width="640">
# Using Adam optimizer
# epoch     1/10    | batch    59/59    | 6.4 b/s
# Test accuracy: 0.9503
# epoch     2/10    | batch    59/59    | 6.7 b/s
# Test accuracy: 0.9801
# epoch     3/10    | batch    59/59    | 6.8 b/s
# Test accuracy: 0.9811
# epoch     4/10    | batch    59/59    | 6.8 b/s
# Test accuracy: 0.9877
# epoch     5/10    | batch    59/59    | 6.8 b/s
# Test accuracy: 0.9841
# epoch     6/10    | batch    59/59    | 6.9 b/s
# Test accuracy: 0.9865
# epoch     7/10    | batch    59/59    | 6.9 b/s
# Test accuracy: 0.9864
# epoch     8/10    | batch    59/59    | 6.9 b/s
# Test accuracy: 0.988
# epoch     9/10    | batch    59/59    | 6.9 b/s
# Test accuracy: 0.9919
# epoch    10/10    | batch    59/59    | 6.9 b/s
# Test accuracy: 0.9902
