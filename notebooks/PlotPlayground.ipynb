# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'AlexNetMini', 128, 50, 'Adam', average=50, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 391
# Number of classes: 10
# Data shape: (32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# epoch     0/49    | batch   390/390   | 24.6 b/s
# Test accuracy: 0.5502
# epoch     1/49    | batch   390/390   | 25.2 b/s
# Test accuracy: 0.6095
# epoch     2/49    | batch   390/390   | 25.3 b/s
# Test accuracy: 0.6336
# epoch     3/49    | batch   319/390   | 25.4 b/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8351c1504317> in <module>()
#       2 import sys; sys.path.insert(0, '..') # gotta add path to project root
#       3 from main import _main
# ----> 4 _main('CIFAR10', 'AlexNetMini', 128, 50, 'Adam', average=50, ylims=None)
#
# /home/share/software/ai_ikkuna/main.py in _main(dataset_str, model_str, batch_size, epochs, optimizer, **kwargs)
#     144
#     145             t0 = time.time()
# --> 146             trainer.train()
#     147             t1 = time.time()
#     148
#
# /home/share/software/ai_ikkuna/train/train.py in train(self)
#     118         data, labels = X.cuda(), Y.cuda()
#     119         self._optimizer.zero_grad()
# --> 120         output = self._model(data)
#     121         loss   = self._loss_function(output, labels)
#     122         loss.backward()
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     466             result = self._slow_forward(*input, **kwargs)
#     467         else:
# --> 468             result = self.forward(*input, **kwargs)
#     469         for hook in self._forward_hooks.values():
#     470             hook_result = hook(self, input, result)
#
# /home/share/software/ai_ikkuna/ikkuna/export/export.py in new_forward_fn(this, *args)
#     280         def new_forward_fn(this, *args):
#     281             self.step()     # we need to step first, else act and grads get different steps
# --> 282             ret = forward_fn(*args)
#     283             return ret
#     284         model.forward = MethodType(new_forward_fn, model)
#
# /home/share/software/ai_ikkuna/models/alexnet.py in forward(self, x)
#      60
#      61     def forward(self, x):
# ---> 62         x = self.features(x)
#      63         x = x.view(x.size(0), 192 * self.H_out * self.W_out)
#      64         x = self.classifier(x)
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     466             result = self._slow_forward(*input, **kwargs)
#     467         else:
# --> 468             result = self.forward(*input, **kwargs)
#     469         for hook in self._forward_hooks.values():
#     470             hook_result = hook(self, input, result)
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /home/share/miniconda3/envs/torch/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     468             result = self.forward(*input, **kwargs)
#     469         for hook in self._forward_hooks.values():
# --> 470             hook_result = hook(self, input, result)
#     471             if hook_result is not None:
#     472                 raise RuntimeError(
#
# /home/share/software/ai_ikkuna/ikkuna/export/export.py in new_activations(self, module, in_, out_)
#     220                 self.export('weight_updates', module, torch.zeros_like(module.weight))
#     221             self.export('weights', module, module.weight)
# --> 222             self._weight_cache[module] = torch.tensor(module.weight)
#     223         if hasattr(module, 'bias') and module.bias is not None:   # bias can be present, but be None
#     224             # in the first train step, there can be no updates, so we just publish zeros, otherwise
#
# KeyboardInterrupt:
