# %%
# this helps in principle, but when this line is executed again, it seems that autoreload gets disabled #wtf
# %load_ext autoreload

# %%
# %matplotlib notebook
# %autoreload 2

import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'AlexNetMini', 128, 10, 'Adam', average=390, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of classes: 10
# Data shape: (50000, 32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# Batches per epoch: 391
# epoch     0/9     | batch   390/390   | 26.3 b/s
# Test accuracy: 0.5243
# epoch     1/9     | batch   390/390   | 26.3 b/s
# Test accuracy: 0.5778
# epoch     2/9     | batch   390/390   | 26.3 b/s
# Test accuracy: 0.6402
# epoch     3/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.6714
# epoch     4/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.6805
# epoch     5/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.6919
# epoch     6/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.6959
# epoch     7/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.7080
# epoch     8/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.7174
# epoch     9/9     | batch   390/390   | 26.4 b/s
# Test accuracy: 0.7325
