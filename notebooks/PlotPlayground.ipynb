# %%
# %matplotlib notebook
import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR100', 'AlexNetMini', 256, 10, 'Adam')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 195
# Number of classes: 100
# Data shape: (32, 32, 3)
# <img src="data:image/png;base64,..." width="640">
# Using Adam optimizer
# epoch     1/10    | batch   195/195   | 17.4 b/s
# Test accuracy: 0.0825
# epoch     2/10    | batch   195/195   | 18.0 b/s
# Test accuracy: 0.1593
# epoch     3/10    | batch   195/195   | 18.1 b/s
# Test accuracy: 0.2268
# epoch     4/10    | batch   195/195   | 18.1 b/s
# Test accuracy: 0.272
# epoch     5/10    | batch   195/195   | 18.1 b/s
# Test accuracy: 0.3067
# epoch     6/10    | batch   195/195   | 18.1 b/s
# Test accuracy: 0.3311
# epoch     7/10    | batch   195/195   | 18.1 b/s
# Test accuracy: 0.3403
# epoch     8/10    | batch   195/195   | 18.2 b/s
# Test accuracy: 0.3637
# epoch     9/10    | batch   195/195   | 18.2 b/s
# Test accuracy: 0.3718
# epoch    10/10    | batch   195/195   | 18.2 b/s
# Test accuracy: 0.3881
