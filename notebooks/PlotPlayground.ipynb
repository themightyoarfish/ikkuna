# %%
# this helps in principle, but when this line is executed again, it seems that autoreload gets disabled #wtf
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib notebook
# %autoreload 2

import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'AlexNetMini', 256, 5, 'Adam', average=10, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 195
# Number of classes: 10
# Data shape: (32, 32, 3)
# Using Adam optimizer
# <img src="data:image/png;base64,..." width="640">
# epoch     0/4     | batch   194/194   | 6.4 b/s
# Test accuracy: 0.4880
# <img src="data:image/png;base64,..." width="640">
# epoch     1/4     | batch   194/194   | 6.5 b/s
# Test accuracy: 0.5481
# epoch     2/4     | batch     0/194   | 6.5 b/s
# <img src="data:image/png;base64,..." width="640">
# epoch     2/4     | batch   194/194   | 6.5 b/s
# Test accuracy: 0.5875
# epoch     3/4     | batch     1/194   | 6.5 b/s
# <img src="data:image/png;base64,..." width="640">
# epoch     3/4     | batch   194/194   | 6.6 b/s
# Test accuracy: 0.6684
# epoch     4/4     | batch     2/194   | 6.6 b/s
# <img src="data:image/png;base64,..." width="640">
# epoch     4/4     | batch   194/194   | 6.6 b/s
# Test accuracy: 0.6956
