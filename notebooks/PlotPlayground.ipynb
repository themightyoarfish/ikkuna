# %%
# this helps in principle, but when this line is executed again, it seems that autoreload gets disabled #wtf
# %load_ext autoreload

# %%
# %matplotlib notebook
# %autoreload 2

import sys; sys.path.insert(0, '..') # gotta add path to project root
from main import _main
_main('CIFAR10', 'DenseNet', 128, 4, 'Adam', average=8, ylims=None)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of classes: 10
# Data shape: (50000, 32, 32, 3)
# Using Adam optimizer
# ../ikkuna/utils/utils.py:78: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# <img src="data:image/png;base64,..." width="640">
# Batches per epoch: 391
# epoch     0/3     | batch   390/390   | 1.3 b/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d4dfc2ea6827> in <module>()
#       4 import sys; sys.path.insert(0, '..') # gotta add path to project root
#       5 from main import _main
# ----> 6 _main('CIFAR10', 'DenseNet', 128, 4, 'Adam', average=8, ylims=None)
#
# /home/share/software/ai_ikkuna/main.py in _main(dataset_str, model_str, batch_size, epochs, optimizer, **kwargs)
#     154                   f'| {1. / (cum_time / n_batches):<3.1f} b/s', end='')
#     155
# --> 156         accuracy = trainer.test(dataset_test)
#     157         print('')
#     158         print(f'Test accuracy: {accuracy:3.4f}')
#
# /home/share/software/ai_ikkuna/train/train.py in test(self, dataset)
#     158             n           += X.shape[0]
#     159             predictions  = self._model(X.cuda()).argmax(1)
# --> 160             num_correct += (predictions.cpu() == _labels).sum()
#     161         return num_correct.item() / n
#
# KeyboardInterrupt:
