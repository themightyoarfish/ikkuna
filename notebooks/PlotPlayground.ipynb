# %%
# %matplotlib notebook
from main import _main
_main('CIFAR10', 'AlexNetMini', 128, 1, 'Adam')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data size: 50000
# Batches per epoch: 391
# Number of classes: 10
# Data shape: (32, 32, 3)
# Using Adam optimizer
# epoch     1/1     | batch   381/391   | 26.6 b/s
# <img src="data:image/png;base64,..." width="640">
# epoch     1/1     | batch   391/391   | 24.9 b/s
# Test accuracy: 0.5087
